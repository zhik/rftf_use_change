# %%
import pandas as pd

# %%
pd.read_csv("./processed_data/filtered_m.csv")
# Out:
#      Unnamed: 0         bbl  15  16  17  18  19     cd               address  \
# 0             0  1000090007  M1  M1  M1  M1  M1  101.0        7 STATE STREET
# 1             1  1000410022  M1  M1  M1  M1  M1  101.0     56 WILLIAM STREET
# 2             2  1000490001  M1  M1  M1  M1  M1  101.0           75 BROADWAY
# 3             3  1000540001  V1  Z9  M1  O2  O2  101.0  130 GREENWICH STREET
# 4             4  1000670030  M1  M1  M1  M1  M1  101.0        44 JOHN STREET
# ..          ...         ...  ..  ..  ..  ..  ..    ...                   ...
# 953         953  1022260007  M1  M1  M1  M1  M1  112.0  111 VERMILYEA AVENUE
# 954         954  1022370018  M1  M1  M1  M1  M1  112.0      21 SEAMAN AVENUE
# 955         955  1022420051  M1  M1  M1  M1  M1  112.0         4967 BROADWAY
# 956         956  1022430384  M1  B1  B1  B1  B1  112.0  93 PARK TERRACE WEST
# 957         957  1022460115  M9  M9  M9  M9  M9  112.0  1815 RIVERSIDE DRIVE
#
#         xcoord    ycoord
# ...
